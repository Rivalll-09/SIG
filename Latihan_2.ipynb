# %% [markdown]
# <a href="https://colab.research.google.com/github/Rivalll-09/SIG/blob/main/Latihan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
from geopandas import datasets, read_file, GeoDataFrame
import matplotlib.pyplot as plt

# %%
zipfile='lsm.zip'
kota=gpd.read_file(zipfile)
kota.head()
# Out:
#   KDPPUM       NAMOBJ                          REMARK KDPBPS FCODE  LUASWH  \
# 0   None   BANDASAKTI  Wilayah Administrasi Kecamatan   None  None     0.0
# 1   None  BLANGMANGAT  Wilayah Administrasi Kecamatan   None  None     0.0
# 2   None    MUARA DUA  Wilayah Administrasi Kecamatan   None  None     0.0
# 3   None   MUARA SATU  Wilayah Administrasi Kecamatan   None  None     0.0
#
#    UUPP SRS_ID   LCODE METADATA  ... WADMKC WIADKC       WADMKK WIADKK WADMPR  \
# 0  None   None  BA0080     None  ...   None   None  LHOKSEUMAWE   None   ACEH
# 1  None   None  BA0080     None  ...   None   None  LHOKSEUMAWE   None   ACEH
# 2  None   None  BA0080     None  ...   None   None  LHOKSEUMAWE   None   ACEH
# 3  None   None  BA0080     None  ...   None   None  LHOKSEUMAWE   None   ACEH
#
#   WIADPR TIPADM SHAPE_Leng SHAPE_Area  \
# 0   None      0   0.162595   0.000888
# 1   None      0   0.474378   0.003945
# 2   None      0   0.298543   0.002193
# 3   None      0   0.377833   0.004098
#
# ...

# %%
kota.plot(column='NAMOBJ')
# Out:
# <Axes: >

# %%
pip install mapclassify

# %%
#-- pip install mapclassify
import mapclassify

# %%
kota.explore(column='NAMOBJ',
             tooltip='NAMOBJ', popup=True,
             tiles='CartoDB positron', cmap='Set1',style_kwds=dict(color='red') )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
kota["coords"] = kota["geometry"].apply(lambda x: x.representative_point().coords[:])
kota["coords"] = [coords[0] for coords in kota["coords"]]
fig, ax = plt.subplots(figsize = (5,5))
kota.plot(ax=ax,   column="NAMOBJ", categorical=True,edgecolor="white", )
for idx, row in kota.iterrows():
   plt.annotate(text=row["NAMOBJ"], xy=row["coords"], horizontalalignment="center", color="black")

# %%
kota.head()
# Out:
#   KDPPUM       NAMOBJ                          REMARK KDPBPS FCODE  LUASWH  \
# 0   None   BANDASAKTI  Wilayah Administrasi Kecamatan   None  None     0.0
# 1   None  BLANGMANGAT  Wilayah Administrasi Kecamatan   None  None     0.0
# 2   None    MUARA DUA  Wilayah Administrasi Kecamatan   None  None     0.0
# 3   None   MUARA SATU  Wilayah Administrasi Kecamatan   None  None     0.0
#
#    UUPP SRS_ID   LCODE METADATA  ... WIADKC       WADMKK WIADKK WADMPR WIADPR  \
# 0  None   None  BA0080     None  ...   None  LHOKSEUMAWE   None   ACEH   None
# 1  None   None  BA0080     None  ...   None  LHOKSEUMAWE   None   ACEH   None
# 2  None   None  BA0080     None  ...   None  LHOKSEUMAWE   None   ACEH   None
# 3  None   None  BA0080     None  ...   None  LHOKSEUMAWE   None   ACEH   None
#
#   TIPADM SHAPE_Leng SHAPE_Area  \
# 0      0   0.162595   0.000888
# 1      0   0.474378   0.003945
# 2      0   0.298543   0.002193
# 3      0   0.377833   0.004098
#
# ...

# %%
import pandas as pd
dt=pd.read_excel('Gis_A5.xlsx')

# %%
dt.head()
# Out:
#         NAMOBJ  KEAHLIAN_IT
# 0   BANDASAKTI          200
# 1  BLANGMANGAT          110
# 2   MUARA SATU          300
# 3    MUARA DUA          250

# %%
kota1=kota.merge(dt,on='NAMOBJ')
kota1.head()
# Out:
#   KDPPUM       NAMOBJ                          REMARK KDPBPS FCODE  LUASWH  \
# 0   None   BANDASAKTI  Wilayah Administrasi Kecamatan   None  None     0.0
# 1   None  BLANGMANGAT  Wilayah Administrasi Kecamatan   None  None     0.0
# 2   None    MUARA DUA  Wilayah Administrasi Kecamatan   None  None     0.0
# 3   None   MUARA SATU  Wilayah Administrasi Kecamatan   None  None     0.0
#
#    UUPP SRS_ID   LCODE METADATA  ...       WADMKK WIADKK WADMPR WIADPR TIPADM  \
# 0  None   None  BA0080     None  ...  LHOKSEUMAWE   None   ACEH   None      0
# 1  None   None  BA0080     None  ...  LHOKSEUMAWE   None   ACEH   None      0
# 2  None   None  BA0080     None  ...  LHOKSEUMAWE   None   ACEH   None      0
# 3  None   None  BA0080     None  ...  LHOKSEUMAWE   None   ACEH   None      0
#
#   SHAPE_Leng SHAPE_Area                                           geometry  \
# 0   0.162595   0.000888  POLYGON Z ((97.13359 5.17511 0.00000, 97.13327...
# ...

# %%
kota1.plot(column='KEAHLIAN_IT', cmap='OrRd', legend=True)
# Out:
# <Axes: >

# %%
kota1.plot(column='KEAHLIAN_IT', cmap='OrRd', scheme='quantiles', figsize=(5,5), legend=True )
# Out:
# <Axes: >

# %%
kota1.plot(column='KEAHLIAN_IT', scheme='quantiles', cmap='OrRd',
           legend=True, figsize=(5,5), k=4,
           legend_kwds={"loc": "center left", "bbox_to_anchor": (1, 0.5)})
# Out:
# <Axes: >
